# %%
import cv2
import numpy as np
import sys
#import glob
#import random
from matplotlib import pyplot as plt
sys.path.append('remove_frame')
from removeFrame import removeFrame
from color_correction import *

# %%
path = r"C:\Users\johan\Desktop\Images\Images\IMG_6560.jpg"
path = r"C:\Users\johan\Desktop\Images\Images\IMG_20221028_160914.jpg"
correctedImg, originalImg, gamma = color_correction(path, 'gammas', 'dist_weigtEuc')
# Out:
# Using gamma-correction, no other correction funcition was choosen
# True blue: [[182.93120586 102.2035621   38.9293058 ]]
# Sampled blue: [254 232  20]
# Corrected blue: [[245 103   0]]
# Gamma: [0.1051155]

# %%
#correctedImg, originalImg, gamma = np.asarray(corrected)
correctedImg = cv2.cvtColor(correctedImg, cv2.COLOR_BGR2RGB)
originalImg = cv2.cvtColor(originalImg, cv2.COLOR_BGR2RGB)
plt.imshow(correctedImg)
plt.show()
plt.imshow(originalImg)
#img = cv2.cvtColor(corrected, cv2.COLOR_BGR2RGB)

# %%
path1 = r"C:\Users\johan\Desktop\Images\Images\IMG_6560.jpg"
path2 = r"C:\Users\johan\Desktop\Images\Images\IMG_20221028_160914.jpg"

img1 = cv2.imread(path1)
print(type(img1))

gamma = 0.3
img1g2 = gammaCorrection(img1, gamma)

plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(img1g2, cv2.COLOR_BGR2RGB))
# Out:
# <class 'numpy.ndarray'>
