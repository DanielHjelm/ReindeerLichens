# %%
import cv2
import numpy as np
import os
from removeFrame import removeFrame
from houghLines import removeFrameUsingHoughLines
import matplotlib.pyplot as plt

# %%
not_working = ['IMG_20221101_124634.jpg','IMG_20221029_144335.jpg','IMG_20221101_130456.jpg','IMG_20221101_123833.jpg','IMG_20221101_125305.jpg','IMG_20221101_120533.jpg','IMG_20221029_144256.jpg','IMG_20221101_123945.jpg','IMG_20221101_123616.jpg','IMG_20221101_120653.jpg','IMG_20221029_150154.jpg','IMG_20221029_143935.jpg','IMG_20221101_124959.jpg','IMG_20221029_144041.jpg','IMG_20221101_125114.jpg','IMG_20221101_120736.jpg','IMG_20221029_150226.jpg','IMG_20221101_114322.jpg','IMG_20221029_144131.jpg','IMG_20221101_124430.jpg','IMG_20221101_130646.jpg','IMG_20221101_120521.jpg','IMG_20221101_130732.jpg','IMG_20221101_114445.jpg','IMG_20221101_114335.jpg','IMG_20221101_130718.jpg','IMG_20221101_120641.jpg','IMG_20221101_114527.jpg','IMG_20221029_144319.jpg','IMG_20221101_125512.jpg','IMG_20221101_124208.jpg','IMG_20221101_114353.jpg','IMG_20221101_130742.jpg','IMG_20221101_123702.jpg','IMG_20221029_144140.jpg','IMG_20221101_125207.jpg','IMG_20221101_120828.jpg','IMG_20221101_130742.jpg','IMG_20221101_123702.jpg','IMG_20221029_144140.jpg','IMG_20221101_125207.jpg','IMG_20221101_120828.jpg','IMG_20221101_123501.jpg','IMG_20221101_120746.jpg','IMG_20221101_125614.jpg','IMG_20221029_150056.jpg','IMG_20221101_130806.jpg','IMG_20221101_130437.jpg','IMG_20221101_125012.jpg','IMG_20221101_123927.jpg','IMG_20221101_123516.jpg','IMG_20221101_114427.jpg','IMG_20221101_130618.jpg','IMG_20221101_123843.jpg','IMG_20221101_123857.jpg','IMG_20221101_124309.jpg','IMG_20221101_120813.jpg','IMG_20221101_124334.jpg','IMG_20221101_124917.jpg','IMG_20221101_123507.jpg','IMG_20221101_124242.jpg','IMG_20221101_130747.jpg','IMG_20221101_124134.jpg','IMG_20221101_130424.jpg','IMG_20221101_125559.jpg','IMG_20221101_130752.jpg','IMG_20221029_144030.jpg','IMG_20221029_145845.jpg','IMG_20221101_130550.jpg','IMG_20221101_125144.jpg','IMG_20221101_124058.jpg','IMG_20221101_121120.jpg','IMG_20221101_123455.jpg','IMG_20221101_124448.jpg','IMG_20221101_125153.jpg','IMG_20221029_145928.jpg','IMG_20221101_114549.jpg','IMG_20221101_123905.jpg','IMG_20221101_114617.jpg','IMG_20221101_124501.jpg','IMG_20221101_114403.jpg','IMG_20221101_114601.jpg','IMG_20221101_125231.jpg','IMG_20221101_121136.jpg','IMG_20221101_123709.jpg','IMG_20221101_123523.jpg','IMG_20221029_144229.jpg','IMG_20221101_123537.jpg','IMG_20221101_124248.jpg','IMG_20221101_130704.jpg', 'IMG_20221101_123802.jpg', 'IMG_20221101_124412.jpg', 'IMG_20221029_144107.jpg', 'IMG_20221101_121032.jpg', 'IMG_20221101_123747.jpg', 'IMG_20221029_150010.jpg', 'IMG_20221101_124412.jpg', 'IMG_20221101_124148.jpg', 'IMG_20221101_124404.jpg', 'IMG_20221101_124011.jpg', 'IMG_20221101_124950.jpg', 'IMG_20221101_123636.jpg', 'IMG_20221101_114500.jpg', 'IMG_20221101_125050.jpg', 'IMG_20221101_125520.jpg', 'IMG_20221101_125246.jpg', 'IMG_20221101_130515.jpg', 'IMG_0172.JPG', 'IMG_20221101_125126.jpg', 'IMG_20221029_144117.jpg', 'IMG_20221101_120857.jpg', 'IMG_20221101_123813.jpg', 'IMG_20221101_125133.jpg', 'IMG_20221101_130502.jpg', 'IMG_20221101_124909.jpg', 'IMG_20221101_121044.jpg', 'IMG_20221029_145910.jpg', 'IMG_20221101_124114.jpg', 'IMG_20221101_125223.jpg', 'IMG_20221101_123915.jpg', 'IMG_20221101_125357.jpg', 'IMG_20221101_130558.jpg', 'IMG_20221101_120952.jpg', 'IMG_20221101_123730.jpg', 'IMG_20221101_125433.jpg', 'IMG_20221101_130638.jpg', 'IMG_20221101_124301.jpg', 'IMG_20221101_120628.jpg', 'IMG_20221101_125036.jpg', 'IMG_20221101_130759.jpg']

# Use Houghlines implementation on frames which uses a folding rule as frame
for i, image in enumerate(not_working):
    
#     if image in not_working or len(image)==12:
#         continue
    
    img = cv2.imread(os.getcwd()+'/tummstock/'+image)

    # Create grayscale image
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


    # Blur the gray image
    blur_gray = cv2.medianBlur(gray, 1)

    # Sharpen image
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(blur_gray, -1, sharpen_kernel)

    # Threshold image
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

    # Create kernel used in the dilation
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (20,20))

    # Dilate the thresholded image
    dilate = cv2.dilate(thresh, kernel, iterations=1)

    # Extract edges
    edges = cv2.Canny(dilate,50,150,apertureSize = 3)

    # Extract lines using HoughLines
    lines = cv2.HoughLinesP(image=edges,rho=1,theta=np.pi/180, threshold=100,lines=np.array([]), minLineLength=10,maxLineGap=500)

    # Check if we actually get some lines
    if lines is not None:

        # Draw lines on black background
        lines_out = np.zeros_like(gray)
        for i in range(np.shape(lines)[0]):
            cv2.line(lines_out, (lines[i][0][0], lines[i][0][1]), (lines[i][0][2], lines[i][0][3]), (255,255,255), 10, cv2.LINE_AA)

        # Using Closing to fill
        kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (100,100))
        closing = cv2.morphologyEx(lines_out, cv2.MORPH_CLOSE, kernel, iterations=1)

        # Find countours
        contours = cv2.findContours(closing, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        contours = contours[0] if len(contours) == 2 else contours[1]

        # Loop through each area
        area_list = []
        for i,contour in enumerate(contours):
            area = cv2.contourArea(contour)
            area_list.append((i,area))

        # Pick correct area
        if len(area_list) == 1:
            tup = area_list[0]
        else:
            tup = sorted(area_list, key=lambda tup: tup[1], reverse=True)[1]
        
        if tup[1] < 200000:
            # Use boundingRect to find area within frame
            x,y,w,h = cv2.boundingRect(contours[tup[0]])

            # Area within frame
            output = np.zeros((w,h))
            output = img[y:y+h, x:x+w]
            
            print(f'Image: {image}')
            print(f'Area: {tup[1]}')
            print(f'Ratio: {np.shape(output)[0]/np.shape(output)[1]}')
            
            
            if (0.9 <= np.shape(output)[0]/np.shape(output)[1] <= 1.1):
                
                plt.imshow(cv2.cvtColor(output, cv2.COLOR_BGR2RGB))
                plt.title('Output')
                plt.show()
# Out:
# Image: IMG_20221101_124634.jpg
# Area: 5196.0
# Ratio: 0.029748283752860413
# Image: IMG_20221029_144335.jpg
# Area: 5557.0
# Ratio: 0.042826552462526764
# Image: IMG_20221101_123833.jpg
# Area: 4909.0
# Ratio: 20.65
# Image: IMG_20221101_125305.jpg
# Area: 14331.0
# Ratio: 0.02973977695167286
# Image: IMG_20221101_120533.jpg
# Area: 20752.5
# Ratio: 0.14347826086956522
# Image: IMG_20221029_144256.jpg
# Area: 2904.0
# Ratio: 18.923076923076923
# Image: IMG_20221101_123945.jpg
# Area: 1693.0
# Ratio: 8.055555555555555
# Image: IMG_20221101_120653.jpg
# Area: 2505.0
# Ratio: 0.06132075471698113
# Image: IMG_20221029_150154.jpg
# Area: 27429.5
# Ratio: 10.918032786885245
# Image: IMG_20221029_143935.jpg
# Area: 32448.0
# Ratio: 0.10766721044045677
# Image: IMG_20221101_124959.jpg
# Area: 1368.0
# Ratio: 8.428571428571429
# Image: IMG_20221029_144041.jpg
# Area: 27099.5
# Ratio: 8.694915254237289
# Image: IMG_20221101_125114.jpg
# Area: 18054.5
# Ratio: 9.127659574468085
# ...

# %%
for i, image in enumerate(os.listdir(os.getcwd()+'/blue')):

    img = cv2.imread(os.getcwd()+'/blue/'+image)


    # Create grayscale image
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

    # GaussionBlur the gray image
    kernel_size = 3
    blur_gray = cv2.GaussianBlur(gray,(kernel_size, kernel_size),0)

    # Threshold image
    thresh = cv2.threshold(blur_gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

    # Create kernel used in the dilation
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (13,13))

    # Dilate the thresholded image
    dilate = cv2.dilate(thresh, kernel, iterations=3)

    # Blur the gray image
    median = cv2.medianBlur(dilate, 21)

#     plt.imshow(median, cmap=)
#     plt.show()

    # Fill holes 
    kernel2 = cv2.getStructuringElement(cv2.MORPH_RECT,(500,1))
    res = cv2.morphologyEx(median,cv2.MORPH_OPEN,kernel2)

    # Fill holes 
    kernel2 = cv2.getStructuringElement(cv2.MORPH_RECT,(1,500))
    res = cv2.morphologyEx(res,cv2.MORPH_OPEN,kernel2)

#     plt.imshow(res, cmap='gray')
#     plt.show()

    # Find the contours in the image
    contours = cv2.findContours(res, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    contours = contours[0] if len(contours) == 2 else contours[1]

    # Loop through each area
    area_list = []
    for i,contour in enumerate(contours):
        area = cv2.contourArea(contour)
        area_list.append((i,area))

    # Find maximum area
    max_tuple = max(area_list, key=lambda tup: tup[1])

    # Use boundingRect to find area within frame
    x,y,w,h = cv2.boundingRect(contours[max_tuple[0]])

    # Area within frame
    output = np.zeros((w,h))
    output = img[y:y+h, x:x+w]

    plt.imshow(cv2.cvtColor(output, cv2.COLOR_BGR2RGB))
    print(image)
    plt.show()

# %%
for i, image in enumerate(os.listdir(os.getcwd()+'/tummstock')):

    img = cv2.imread(os.getcwd()+'/tummstock/'+image)


    # Create grayscale image
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

    # GaussionBlur the gray image
    kernel_size = 3
    blur_gray = cv2.GaussianBlur(gray,(kernel_size, kernel_size),0)

    # Threshold image
    thresh = cv2.threshold(blur_gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

    # Create kernel used in the dilation
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (13,13))

    # Dilate the thresholded image
    dilate = cv2.dilate(thresh, kernel, iterations=3)

    # Blur the gray image
    median = cv2.medianBlur(dilate, 21)

#     plt.imshow(median, cmap=)
#     plt.show()

    # Fill holes 
    kernel2 = cv2.getStructuringElement(cv2.MORPH_RECT,(500,1))
    res = cv2.morphologyEx(median,cv2.MORPH_OPEN,kernel2)

    # Fill holes 
    kernel2 = cv2.getStructuringElement(cv2.MORPH_RECT,(1,500))
    res = cv2.morphologyEx(res,cv2.MORPH_OPEN,kernel2)

#     plt.imshow(res, cmap='gray')
#     plt.show()

    # Find the contours in the image
    contours = cv2.findContours(res, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    contours = contours[0] if len(contours) == 2 else contours[1]

    # Loop through each area
    area_list = []
    for i,contour in enumerate(contours):
        area = cv2.contourArea(contour)
        area_list.append((i,area))

    # Find maximum area
    max_tuple = max(area_list, key=lambda tup: tup[1])

    # Use boundingRect to find area within frame
    x,y,w,h = cv2.boundingRect(contours[max_tuple[0]])

    # Area within frame
    output = np.zeros((w,h))
    output = img[y:y+h, x:x+w]

    plt.imshow(cv2.cvtColor(output, cv2.COLOR_BGR2RGB))
    print(image)
    plt.show()

# %%
# Use implementation on frames which uses a blue frame
for i, image in enumerate(os.listdir(os.getcwd()+'/blue')):
    
    img = cv2.imread(os.getcwd()+'/blue/'+image)
    
    without_frame = removeFrame(os.getcwd()+'/blue/'+image)
    
    plt.imshow(without_frame)
    plt.xlabel(image)
    plt.title('Image without frame')
    plt.show()
    
#     if i :
#         break

# %%
0.9 <= np.shape(output)[0]/np.shape(output)[0] <= 1.1
# Out:
# True

# %%
# not_working = ['IMG_20221101_124634.jpg','IMG_20221029_144335.jpg','IMG_20221101_130456.jpg','IMG_20221101_123833.jpg','IMG_20221101_125305.jpg','IMG_20221101_120533.jpg','IMG_20221029_144256.jpg','IMG_20221101_123945.jpg','IMG_20221101_123616.jpg','IMG_20221101_120653.jpg','IMG_20221029_150154.jpg','IMG_20221029_143935.jpg','IMG_20221101_124959.jpg','IMG_20221029_144041.jpg','IMG_20221101_125114.jpg','IMG_20221101_120736.jpg','IMG_20221029_150226.jpg','IMG_20221101_114322.jpg','IMG_20221029_144131.jpg','IMG_20221101_124430.jpg','IMG_20221101_130646.jpg','IMG_20221101_120521.jpg','IMG_20221101_130732.jpg','IMG_20221101_114445.jpg','IMG_20221101_114335.jpg','IMG_20221101_130718.jpg','IMG_20221101_120641.jpg','IMG_20221101_114527.jpg','IMG_20221029_144319.jpg','IMG_20221101_125512.jpg','IMG_20221101_124208.jpg','IMG_20221101_114353.jpg','IMG_20221101_130742.jpg','IMG_20221101_123702.jpg','IMG_20221029_144140.jpg','IMG_20221101_125207.jpg','IMG_20221101_120828.jpg','IMG_20221101_130742.jpg','IMG_20221101_123702.jpg','IMG_20221029_144140.jpg','IMG_20221101_125207.jpg','IMG_20221101_120828.jpg','IMG_20221101_123501.jpg','IMG_20221101_120746.jpg','IMG_20221101_125614.jpg','IMG_20221029_150056.jpg','IMG_20221101_130806.jpg','IMG_20221101_130437.jpg','IMG_20221101_125012.jpg','IMG_20221101_123927.jpg','IMG_20221101_123516.jpg','IMG_20221101_114427.jpg','IMG_20221101_130618.jpg','IMG_20221101_123843.jpg','IMG_20221101_123857.jpg','IMG_20221101_124309.jpg','IMG_20221101_120813.jpg','IMG_20221101_124334.jpg','IMG_20221101_124917.jpg','IMG_20221101_123507.jpg','IMG_20221101_124242.jpg','IMG_20221101_130747.jpg','IMG_20221101_124134.jpg','IMG_20221101_130424.jpg','IMG_20221101_125559.jpg','IMG_20221101_130752.jpg','IMG_20221029_144030.jpg','IMG_20221029_145845.jpg','IMG_20221101_130550.jpg','IMG_20221101_125144.jpg','IMG_20221101_124058.jpg','IMG_20221101_121120.jpg','IMG_20221101_123455.jpg','IMG_20221101_124448.jpg','IMG_20221101_125153.jpg','IMG_20221029_145928.jpg','IMG_20221101_114549.jpg','IMG_20221101_123905.jpg','IMG_20221101_114617.jpg','IMG_20221101_124501.jpg','IMG_20221101_114403.jpg','IMG_20221101_114601.jpg','IMG_20221101_125231.jpg','IMG_20221101_121136.jpg','IMG_20221101_123709.jpg','IMG_20221101_123523.jpg','IMG_20221029_144229.jpg','IMG_20221101_123537.jpg','IMG_20221101_124248.jpg','IMG_20221101_130704.jpg', 'IMG_20221101_123802.jpg', 'IMG_20221101_124412', 'IMG_20221029_144107.jpg', 'IMG_20221101_121032.jpg', 'IMG_20221101_123747.jpg', 'IMG_20221029_150010.jpg', 'IMG_20221101_124412.jpg', 'IMG_20221101_124148.jpg', 'IMG_20221101_124404.jpg', 'IMG_20221101_124011.jpg', 'IMG_20221101_124950.jpg', 'IMG_20221101_123636.jpg', 'IMG_20221101_114500.jpg', 'IMG_20221101_125050.jpg', 'IMG_20221101_125520.jpg', 'IMG_20221101_125246.jpg', 'IMG_20221101_130515.jpg', 'IMG_0172.JPG', 'IMG_20221101_125126.jpg', 'IMG_20221029_144117.jpg', 'IMG_20221101_120857.jpg', 'IMG_20221101_123813.jpg', 'IMG_20221101_125133.jpg', 'IMG_20221101_130502.jpg', 'IMG_20221101_124909.jpg', 'IMG_20221101_121044.jpg', 'IMG_20221029_145910.jpg', 'IMG_20221101_124114.jpg', 'IMG_20221101_125223.jpg', 'IMG_20221101_123915.jpg', 'IMG_20221101_125357.jpg', 'IMG_20221101_130558.jpg', 'IMG_20221101_120952.jpg', 'IMG_20221101_123730.jpg', 'IMG_20221101_125433.jpg', 'IMG_20221101_130638.jpg', 'IMG_20221101_124301.jpg', 'IMG_20221101_120628.jpg', 'IMG_20221101_125036.jpg', 'IMG_20221101_130759.jpg']

# Use Houghlines implementation on frames which uses a folding rule as frame
for i, image in enumerate(os.listdir(os.getcwd()+'/tummstock')):
    
#     if image in not_working or len(image)==12:
#         continue
    
    img = cv2.imread(os.getcwd()+'/tummstock/'+image)
    
    print(image)
    
    without_frame = removeFrameUsingHoughLines(os.getcwd()+'/tummstock/'+image)
    
    plt.imshow(without_frame)
    plt.xlabel(image)
    plt.title('Image without frame')
    plt.show()
