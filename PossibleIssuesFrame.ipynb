# %%
import numpy as np
import glob
import random
from remove_frame.houghLines import removeFrameUsingHoughLines as removeFrame
from PIL import Image
from matplotlib import pyplot as plt

# %%
# Possible issues with frame detection
path_start = r"C:\Users\johan\Desktop\Images\Images"
possible_issues = [r"\IMG_6517.jpg",r"\IMG_20221101_114527.jpg",r"\IMG_6685.jpg",r"\IMG_20221101_125050.jpg",r"\IMG_20221028_154710.jpg"]

fig = plt.figure(figsize=(len(path),2))
for i in possible_issues:
    n = removeFrame(path_start + i)
    plt.imshow(n)
    plt.title('Image without frame')
    plt.xlabel(i)
    plt.show()
    ori = cv.imread(path_start + i)
    plt.imshow(ori)
    plt.title('Original')
    plt.xlabel(i)
    plt.show()

for i in path:
    n = removeFrame(i)
    plt.subplot
